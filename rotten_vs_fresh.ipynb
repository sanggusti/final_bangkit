# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()

# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json

# Next, install the Kaggle API client.
# !pip install -q kaggle

# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

! kaggle datasets download -d sriramr/fruits-fresh-and-rotten-for-classification
# Out:
#      <input type="file" id="files-8960a579-8dc1-4181-8381-9bfdb0e26eb1" name="files[]" multiple disabled />
#      <output id="result-8960a579-8dc1-4181-8381-9bfdb0e26eb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# -rw-r--r-- 1 root root 69 Jun 11 13:20 kaggle.json
# Downloading fruits-fresh-and-rotten-for-classification.zip to /content
# 100% 3.57G/3.58G [01:05<00:00, 47.7MB/s]
# 100% 3.58G/3.58G [01:05<00:00, 58.6MB/s]

# %%
import zipfile
import os

curDir = os.getcwd()
print(curDir)

local_zip = '/content/fruits-fresh-and-rotten-for-classification.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')

zip_ref.close()
# Out:
# /content

# %%
import random
from keras.preprocessing.image import load_img
import matplotlib.pyplot as plt

filenames = os.listdir('/content/dataset/train/freshoranges')
sample = random.choice(filenames)
image = load_img('/content/dataset/train/freshoranges/'+sample)
plt.imshow(image)
print(image.size)
# Out:
# Using TensorFlow backend.
# (356, 270)

# %%
import shutil

shutil.rmtree('/content/dataset/dataset')
os.remove('fruits-fresh-and-rotten-for-classification.zip')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
        '/content/dataset/train', 
        target_size=(150, 150),
        batch_size=15,
	      class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
        '/content/dataset/test',
        target_size=(150, 150),
        batch_size=15,
	      class_mode='categorical')
# Out:
# Found 10901 images belonging to 6 classes.
# Found 2698 images belonging to 6 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, GlobalMaxPooling2D
from keras import backend as K

model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3)))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(GlobalMaxPooling2D())


# model.add(Dropout(0.25))
# model.add(Dense(128))
# model.add(Activation('relu'))
# model.add(Dropout(0.25))
# model.add(Dense(128))
# model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(6))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 64)      1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 148, 148, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 72, 72, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 32)        18464
# _________________________________________________________________
# activation_3 (Activation)    (None, 34, 34, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16, 16, 256)       8448
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 393222
# _________________________________________________________________
# activation_6 (Activation)    (None, 6)                 0
# =================================================================
# Total params: 468,102
# Trainable params: 468,102
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
              train_generator,    
              epochs=30, 
              validation_data = validation_generator,
              verbose=1
              )
# Out:
# Epoch 1/30
# 727/727 [==============================] - 75s 103ms/step - loss: 0.5970 - accuracy: 0.7803 - val_loss: 0.1729 - val_accuracy: 0.8866
# Epoch 2/30
# 727/727 [==============================] - 67s 92ms/step - loss: 0.2956 - accuracy: 0.8951 - val_loss: 0.1823 - val_accuracy: 0.9110
# Epoch 3/30
# 727/727 [==============================] - 67s 92ms/step - loss: 0.2277 - accuracy: 0.9173 - val_loss: 0.2925 - val_accuracy: 0.9318
# Epoch 4/30
# 727/727 [==============================] - 65s 89ms/step - loss: 0.1759 - accuracy: 0.9382 - val_loss: 0.1175 - val_accuracy: 0.9466
# Epoch 5/30
# 727/727 [==============================] - 65s 89ms/step - loss: 0.1324 - accuracy: 0.9526 - val_loss: 0.0759 - val_accuracy: 0.9481
# Epoch 6/30
# 727/727 [==============================] - 65s 89ms/step - loss: 0.1159 - accuracy: 0.9598 - val_loss: 0.2800 - val_accuracy: 0.9218
# Epoch 7/30
# 727/727 [==============================] - 66s 90ms/step - loss: 0.0920 - accuracy: 0.9664 - val_loss: 0.0093 - val_accuracy: 0.9622
# Epoch 8/30
# 727/727 [==============================] - 63s 87ms/step - loss: 0.0750 - accuracy: 0.9728 - val_loss: 0.1420 - val_accuracy: 0.9703
# Epoch 9/30
# 727/727 [==============================] - 65s 89ms/step - loss: 0.0654 - accuracy: 0.9765 - val_loss: 7.4147e-04 - val_accuracy: 0.9703
# Epoch 10/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0557 - accuracy: 0.9795 - val_loss: 0.2779 - val_accuracy: 0.9544
# Epoch 11/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0464 - accuracy: 0.9849 - val_loss: 0.0124 - val_accuracy: 0.9715
# Epoch 12/30
# 727/727 [==============================] - 63s 87ms/step - loss: 0.0434 - accuracy: 0.9841 - val_loss: 0.0627 - val_accuracy: 0.9696
# Epoch 13/30
# 727/727 [==============================] - 63s 87ms/step - loss: 0.0382 - accuracy: 0.9867 - val_loss: 0.0028 - val_accuracy: 0.9807
# Epoch 14/30
# 727/727 [==============================] - 63s 87ms/step - loss: 0.0332 - accuracy: 0.9883 - val_loss: 0.0654 - val_accuracy: 0.9789
# Epoch 15/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.0021 - val_accuracy: 0.9748
# Epoch 16/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0270 - accuracy: 0.9903 - val_loss: 5.8414e-05 - val_accuracy: 0.9678
# Epoch 17/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0218 - accuracy: 0.9921 - val_loss: 0.1840 - val_accuracy: 0.9696
# Epoch 18/30
# 727/727 [==============================] - 65s 90ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.0021 - val_accuracy: 0.9841
# Epoch 19/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.0029 - val_accuracy: 0.9859
# Epoch 20/30
# 727/727 [==============================] - 64s 88ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 1.7547e-04 - val_accuracy: 0.9874
# Epoch 21/30
# 727/727 [==============================] - 66s 91ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.1833 - val_accuracy: 0.9800
# Epoch 22/30
# 727/727 [==============================] - 66s 91ms/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.2228 - val_accuracy: 0.9874
# Epoch 23/30
# 727/727 [==============================] - 67s 92ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 6.7006e-05 - val_accuracy: 0.9907
# Epoch 24/30
# 727/727 [==============================] - 64s 89ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0448 - val_accuracy: 0.9863
# Epoch 25/30
# 727/727 [==============================] - 65s 89ms/step - loss: 0.0141 - accuracy: 0.9945 - val_loss: 0.1778 - val_accuracy: 0.9796
# Epoch 26/30
# 727/727 [==============================] - 65s 90ms/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 0.0065 - val_accuracy: 0.9826
# Epoch 27/30
# 727/727 [==============================] - 65s 89ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0025 - val_accuracy: 0.9848
# Epoch 28/30
# 727/727 [==============================] - 65s 90ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 9.5447e-04 - val_accuracy: 0.9833
# Epoch 29/30
# 727/727 [==============================] - 63s 86ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.1329 - val_accuracy: 0.9889
# Epoch 30/30
# 727/727 [==============================] - 64s 87ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 6.4307e-05 - val_accuracy: 0.9907

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()


plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
# https://storage.googleapis.com/laurencemoroney-blog.appspot.com/rps-validation.zip

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150, 150,3))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=15)
  # print(fn)
  # print(classes)
  class_list = ['fresh apple', 'fresh banana', 'fresh orange', 'rotten apple', 'rotten banana', 'rotten orange']
  print('{} is a {}'.format(fn, class_list[classes.argmax(axis=-1)[0]]))
# Out:
#      <input type="file" id="files-de786d49-b05f-4ac7-a852-db960db30e0c" name="files[]" multiple disabled />
#      <output id="result-de786d49-b05f-4ac7-a852-db960db30e0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rotten-overripe-soft-banana-on-white-background-DBW8WH.jpg to rotten-overripe-soft-banana-on-white-background-DBW8WH (1).jpg
# rotten-overripe-soft-banana-on-white-background-DBW8WH.jpg is a rotten banana

# %%
model.save('rotten-fresh-model.h5') 

# Save the entire model as a SavedModel.
# !mkdir -p saved_model
# model.save('saved_model/my_model')
